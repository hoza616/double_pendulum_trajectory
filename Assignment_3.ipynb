# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame

import torch
import torchvision
import torchvision.datasets as dsets             #for downloading dataset
import torchvision.transforms as transforms      #for transforming dataset into tensors

from torch import nn
from torch.autograd import Variable
import torchvision.transforms.functional as fn

from sklearn.model_selection import train_test_split

from PIL import Image

from time import time

# %% [markdown]
# ## Importing Data

# %%
data = pd.read_csv('double_pendulum_data.csv', sep=',')
display(data.head(24))

data = data.to_numpy()
# Out:
#      theta_1   theta_2  dtheta_1  dtheta_2
# 0  -0.136273 -2.354292  3.269050  4.259279
# 1  -0.104119 -2.311299  3.158434  4.338537
# 2  -0.073172 -2.267539  3.027628  4.412529
# 3  -0.043633 -2.223066  2.876737  4.481144
# 4  -0.015703 -2.177934  2.706071  4.544425
# 5   0.010424 -2.132195  2.516133  4.602587
# 6   0.034558 -2.085898  2.307608  4.656024
# 7   0.056517 -2.039088  2.081324  4.705308
# 8   0.076128 -1.991803  1.838220  4.751197
# 9   0.093228 -1.944072  1.579290  4.794624
# 10  0.107664 -1.895915  1.305526  4.836693
# 11  1.043913 -0.524939  1.545162 -4.775724
# 12  1.057013 -0.572417  1.076430 -4.722611
# 13  1.065468 -0.619439  0.615858 -4.683844
# 14  1.069350 -0.666130  0.161297 -4.655867
# 15  1.068711 -0.712581 -0.288281 -4.635369
# 16  1.063600 -0.758852 -0.732950 -4.619179
# 17  1.054071 -0.804969 -1.171962 -4.604215
# 18  1.040185 -0.850930 -1.603870 -4.587465
# 19  1.022024 -0.896703 -2.026661 -4.565994
# 20  0.999690 -0.942225 -2.437885 -4.536979
# 21  0.973314 -0.987408 -2.834807 -4.497768
# 22 -1.836644  2.602888 -0.079700  4.136839
# 23 -1.837682  2.643980 -0.126525  4.082466

# %% [markdown]
# ## Train/Test Split Data

# %%
data_train, data_test = train_test_split(data, train_size=0.75)

print(data_train.shape)
print(data_test.shape)
# Out:
# (1650, 4)
# (550, 4)

# %%
# seq_len = 10
device = 'cpu'

Xm  = np.mean(data_train, axis=0)
Xv  = 2*np.std(data_train, axis=0)

# print(Xm.shape)
# print(Xv.shape)

Xm_train = np.tile(Xm,(data_train.shape[0],1))
Xv_train = np.tile(Xv,(data_train.shape[0],1))

# print(Xm_train.shape)
# print(Xv_train.shape)

Xm_test  = np.tile(Xm,(data_test.shape[0],1))
Xv_test  = np.tile(Xv,(data_test.shape[0],1))

data_train = (data_train - Xm_train)/Xv_train
data_test  = (data_test - Xm_test)/Xv_test

X_train, Y_train = data_train[:,:], data_train[:,:]
X_test, Y_test   = data_test[:,:], data_test[:,:]

print(X_train.shape)
print(Y_train.shape)

x_train, y_train = torch.from_numpy(X_train).float().to(device), torch.from_numpy(Y_train).float().to(device)
x_test, y_test   = torch.from_numpy(X_test).float().to(device), torch.from_numpy(Y_test).float().to(device)

print(x_train.size())
print(y_train.size())
# Out:
# (1650, 4)
# (1650, 4)
# torch.Size([1650, 4])
# torch.Size([1650, 4])

# %% [markdown]
# ## Convert to Tensors

# %%
batch_size = 11
def generate_batch_data(x, y, batch_size):
    for batch, i in enumerate(range(0, len(x), batch_size)):
        x_batch = x[i : i + batch_size-1,:]
        y_batch = y[i+1 : i + batch_size,:]
        yield x_batch, y_batch, batch

# %%
for x_batch, y_batch, batch in generate_batch_data(x_train, y_train, batch_size):
    print('batch:',batch)
    print('x_batch size:', x_batch.shape)
    print('y_batch size:', y_batch.shape)
# Out:
# batch: 0
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 1
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 2
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 3
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 4
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 5
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 6
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 7
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 8
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 9
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 10
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 11
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 12
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 13
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 14
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 15
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 16
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 17
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 18
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 19
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 20
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 21
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 22
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 23
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 24
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 25
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 26
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 27
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 28
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 29
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 30
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 31
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 32
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 33
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 34
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 35
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 36
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 37
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 38
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 39
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 40
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 41
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 42
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 43
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 44
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 45
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 46
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 47
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 48
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 49
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 50
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 51
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 52
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 53
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 54
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 55
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 56
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 57
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 58
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 59
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 60
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 61
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 62
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 63
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 64
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 65
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 66
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 67
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 68
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 69
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 70
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 71
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 72
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 73
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 74
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 75
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 76
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 77
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 78
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 79
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 80
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 81
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 82
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 83
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 84
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 85
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 86
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 87
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 88
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 89
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 90
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 91
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 92
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 93
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 94
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 95
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 96
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 97
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 98
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 99
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 100
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 101
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 102
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 103
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 104
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 105
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 106
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 107
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 108
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 109
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 110
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 111
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 112
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 113
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 114
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 115
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 116
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 117
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 118
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 119
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 120
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 121
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 122
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 123
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 124
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 125
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 126
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 127
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 128
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 129
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 130
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 131
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 132
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 133
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 134
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 135
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 136
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 137
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 138
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 139
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 140
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 141
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 142
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 143
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 144
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 145
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 146
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 147
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 148
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])
# batch: 149
# x_batch size: torch.Size([10, 4])
# y_batch size: torch.Size([10, 4])

# %% [markdown]
# ## Hyper Parameters

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 


learning_rate = 0.1

input_size = 4
sequence_length = 1
hidden_size = 10
num_layers = 2
output_size = 4

# %% [markdown]
# ## Creating NN Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
#         self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        # -> x needs to be: (batch_size, seq, input_size)
        
        # or:
        #self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        # Set initial hidden states (and cell states for LSTM)
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        
        # x: (n, 28, 28), h0: (2, n, 128)
        
        # Forward propagate RNN
#         out, _ = self.rnn(x, h0)  
        # or:
        out, _ = self.lstm(x, (h0,c0))  
        
        # out: tensor of shape (batch_size, seq_length, hidden_size)
        # out: (n, 28, 128)
        
        # Decode the hidden state of the last time step
#         out = out[:, -1, :]
        # out: (n, 128)
         
        out = self.fc(out)
        # out: (n, 10)
        out = out
        return out

model = RNN(input_size, hidden_size, num_layers, output_size).to(device)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Check if model works

# %%
# sample = training_data[0:10,0:4].reshape(10,1,4)
# output = model(sample)
# print('sample_ip',sample.size())
# print('output_size', output.size())
# print('model works')
# label = training_data[(num_samples*11):(num_samples*11)+10,0:4].reshape(10,1,4)
# print(label.size())

# # predicted_output = model(training_data[(num_samples*11),0:4].reshape(1,1,4))
# loss = criterion(output, training_data[1:11,0:4].reshape(10,1,4))
# print(loss)

# %% [markdown]
# ## Training

# %%
Loss = np.zeros(num_epochs).astype('int32')
start_time = time()
num_samples = 149
num_epochs = 200

for epoch in range(num_epochs):
    for x_batch, y_batch, batch in generate_batch_data(x_train, y_train, batch_size):
#         print('sahpe x', x_batch.shape)
#         print('sahpe y', y_batch.shape)
        
        predicted_output = model(x_batch.reshape(10,1,4))
        loss = criterion(predicted_output, y_batch.reshape(10,1,4))
        optimizer.zero_grad()
        loss.backward()
#         print(i)
#         torch.nn.utils.clip_grad_norm_(model.parameters(), 100)

        ## update model params
        optimizer.step()

    train_running_loss += loss.detach().item()
        
    print('Epoch: %d \t Loss: %.4f \t ' \
             %(epoch, loss ))
#     Loss[epoch] = loss

end_time = time()
print('Total Duration: {}'.format(end_time - start_time))
# Out:
# Epoch: 0 	 Loss: 7.8279
# Epoch: 1 	 Loss: 7.7765
# Epoch: 2 	 Loss: 7.8670
# Epoch: 3 	 Loss: 7.8342
# Epoch: 4 	 Loss: 7.8821
# Epoch: 5 	 Loss: 7.8349
# Epoch: 6 	 Loss: 7.8453
# Epoch: 7 	 Loss: 7.8470
# Epoch: 8 	 Loss: 7.8359
# Epoch: 9 	 Loss: 7.8366
# Epoch: 10 	 Loss: 7.8387
# Epoch: 11 	 Loss: 7.8511
# Epoch: 12 	 Loss: 7.8343
# Epoch: 13 	 Loss: 7.8299
# Epoch: 14 	 Loss: 7.8349
# Epoch: 15 	 Loss: 7.8347
# Epoch: 16 	 Loss: 7.8330
# Epoch: 17 	 Loss: 7.7802
# Epoch: 18 	 Loss: 7.8347
# Epoch: 19 	 Loss: 7.8343
# Epoch: 20 	 Loss: 7.8661
# Epoch: 21 	 Loss: 7.8447
# Epoch: 22 	 Loss: 7.8532
# Epoch: 23 	 Loss: 7.8337
# Epoch: 24 	 Loss: 7.8345
# Epoch: 25 	 Loss: 7.8347
# Epoch: 26 	 Loss: 7.8347
# Epoch: 27 	 Loss: 7.8346
# Epoch: 28 	 Loss: 7.8349
# Epoch: 29 	 Loss: 7.8351
# Epoch: 30 	 Loss: 7.8350
# Epoch: 31 	 Loss: 7.8351
# Epoch: 32 	 Loss: 7.8349
# Epoch: 33 	 Loss: 7.8345
# Epoch: 34 	 Loss: 7.8353
# Epoch: 35 	 Loss: 7.8363
# Epoch: 36 	 Loss: 7.8355
# Epoch: 37 	 Loss: 7.8357
# Epoch: 38 	 Loss: 7.8317
# Epoch: 39 	 Loss: 7.8354
# Epoch: 40 	 Loss: 7.8357
# Epoch: 41 	 Loss: 7.8354
# Epoch: 42 	 Loss: 7.8355
# Epoch: 43 	 Loss: 7.8514
# Epoch: 44 	 Loss: 7.8367
# Epoch: 45 	 Loss: 7.8354
# Epoch: 46 	 Loss: 7.8354
# Epoch: 47 	 Loss: 7.8354
# Epoch: 48 	 Loss: 7.8354
# Epoch: 49 	 Loss: 7.8354
# Epoch: 50 	 Loss: 7.8354
# Epoch: 51 	 Loss: 7.8355
# Epoch: 52 	 Loss: 7.8357
# Epoch: 53 	 Loss: 7.8533
# Epoch: 54 	 Loss: 7.8359
# Epoch: 55 	 Loss: 7.8368
# Epoch: 56 	 Loss: 7.8563
# Epoch: 57 	 Loss: 7.8352
# Epoch: 58 	 Loss: 7.8353
# Epoch: 59 	 Loss: 7.8353
# Epoch: 60 	 Loss: 7.8360
# Epoch: 61 	 Loss: 7.8353
# Epoch: 62 	 Loss: 7.8353
# Epoch: 63 	 Loss: 7.8353
# Epoch: 64 	 Loss: 7.8354
# Epoch: 65 	 Loss: 7.8354
# Epoch: 66 	 Loss: 7.8354
# Epoch: 67 	 Loss: 7.8354
# Epoch: 68 	 Loss: 7.8354
# Epoch: 69 	 Loss: 7.8354
# Epoch: 70 	 Loss: 7.8354
# Epoch: 71 	 Loss: 7.8354
# Epoch: 72 	 Loss: 7.8354
# Epoch: 73 	 Loss: 7.8312
# Epoch: 74 	 Loss: 7.8357
# Epoch: 75 	 Loss: 7.8354
# Epoch: 76 	 Loss: 7.8354
# Epoch: 77 	 Loss: 7.8353
# Epoch: 78 	 Loss: 7.8355
# Epoch: 79 	 Loss: 7.8354
# Epoch: 80 	 Loss: 7.8354
# Epoch: 81 	 Loss: 7.8354
# Epoch: 82 	 Loss: 7.8353
# Epoch: 83 	 Loss: 7.8348
# Epoch: 84 	 Loss: 7.8353
# Epoch: 85 	 Loss: 7.8354
# Epoch: 86 	 Loss: 7.8356
# Epoch: 87 	 Loss: 7.8355
# Epoch: 88 	 Loss: 7.8266
# Epoch: 89 	 Loss: 7.8357
# Epoch: 90 	 Loss: 7.8361
# Epoch: 91 	 Loss: 7.8354
# Epoch: 92 	 Loss: 7.8357
# Epoch: 93 	 Loss: 7.8385
# Epoch: 94 	 Loss: 7.8415
# Epoch: 95 	 Loss: 7.8355
# Epoch: 96 	 Loss: 7.8356
# Epoch: 97 	 Loss: 7.8368
# Epoch: 98 	 Loss: 7.8335
# Epoch: 99 	 Loss: 7.8375
# Epoch: 100 	 Loss: 7.8357
# Epoch: 101 	 Loss: 7.8352
# Epoch: 102 	 Loss: 7.8348
# Epoch: 103 	 Loss: 7.8319
# Epoch: 104 	 Loss: 7.8345
# Epoch: 105 	 Loss: 7.8462
# Epoch: 106 	 Loss: 7.8356
# Epoch: 107 	 Loss: 7.8356
# Epoch: 108 	 Loss: 7.8346
# Epoch: 109 	 Loss: 7.8401
# Epoch: 110 	 Loss: 7.8355
# Epoch: 111 	 Loss: 7.8354
# Epoch: 112 	 Loss: 7.8354
# Epoch: 113 	 Loss: 7.8354
# Epoch: 114 	 Loss: 7.8353
# Epoch: 115 	 Loss: 7.8349
# Epoch: 116 	 Loss: 7.8353
# Epoch: 117 	 Loss: 7.8354
# Epoch: 118 	 Loss: 7.8353
# Epoch: 119 	 Loss: 7.8355
# Epoch: 120 	 Loss: 7.8429
# Epoch: 121 	 Loss: 7.8347
# Epoch: 122 	 Loss: 7.8356
# Epoch: 123 	 Loss: 7.8355
# Epoch: 124 	 Loss: 7.8353
# Epoch: 125 	 Loss: 7.8355
# Epoch: 126 	 Loss: 7.8204
# Epoch: 127 	 Loss: 7.8356
# Epoch: 128 	 Loss: 7.8355
# Epoch: 129 	 Loss: 7.8355
# Epoch: 130 	 Loss: 7.8355
# Epoch: 131 	 Loss: 7.8355
# Epoch: 132 	 Loss: 7.8355
# Epoch: 133 	 Loss: 7.8355
# Epoch: 134 	 Loss: 7.8355
# Epoch: 135 	 Loss: 7.8355
# Epoch: 136 	 Loss: 7.8355
# Epoch: 137 	 Loss: 7.8355
# Epoch: 138 	 Loss: 7.8355
# Epoch: 139 	 Loss: 7.8355
# Epoch: 140 	 Loss: 7.8355
# Epoch: 141 	 Loss: 7.8355
# Epoch: 142 	 Loss: 7.8354
# Epoch: 143 	 Loss: 7.8354
# Epoch: 144 	 Loss: 7.8354
# Epoch: 145 	 Loss: 7.8354
# Epoch: 146 	 Loss: 7.8354
# Epoch: 147 	 Loss: 7.8354
# Epoch: 148 	 Loss: 7.8354
# Epoch: 149 	 Loss: 7.8354
# Epoch: 150 	 Loss: 7.8354
# Epoch: 151 	 Loss: 7.8354
# Epoch: 152 	 Loss: 7.8354
# Epoch: 153 	 Loss: 7.8354
# Epoch: 154 	 Loss: 7.8354
# Epoch: 155 	 Loss: 7.8354
# Epoch: 156 	 Loss: 7.8354
# Epoch: 157 	 Loss: 7.8354
# Epoch: 158 	 Loss: 7.8354
# Epoch: 159 	 Loss: 7.8354
# Epoch: 160 	 Loss: 7.8354
# Epoch: 161 	 Loss: 7.8354
# Epoch: 162 	 Loss: 7.8354
# Epoch: 163 	 Loss: 7.8354
# Epoch: 164 	 Loss: 7.8354
# Epoch: 165 	 Loss: 7.8354
# Epoch: 166 	 Loss: 7.8354
# Epoch: 167 	 Loss: 7.8354
# Epoch: 168 	 Loss: 7.8354
# Epoch: 169 	 Loss: 7.8354
# Epoch: 170 	 Loss: 7.8354
# Epoch: 171 	 Loss: 7.8354
# Epoch: 172 	 Loss: 7.8354
# Epoch: 173 	 Loss: 7.8354
# Epoch: 174 	 Loss: 7.8354
# Epoch: 175 	 Loss: 7.8354
# Epoch: 176 	 Loss: 7.8354
# Epoch: 177 	 Loss: 7.8354
# Epoch: 178 	 Loss: 7.8354
# Epoch: 179 	 Loss: 7.8354
# Epoch: 180 	 Loss: 7.8354
# Epoch: 181 	 Loss: 7.8354
# Epoch: 182 	 Loss: 7.8354
# Epoch: 183 	 Loss: 7.8354
# Epoch: 184 	 Loss: 7.8354
# Epoch: 185 	 Loss: 7.8313
# Epoch: 186 	 Loss: 7.8354
# Epoch: 187 	 Loss: 7.8354
# Epoch: 188 	 Loss: 7.8354
# Epoch: 189 	 Loss: 7.8354
# Epoch: 190 	 Loss: 7.8354
# Epoch: 191 	 Loss: 7.8354
# Epoch: 192 	 Loss: 7.8354
# Epoch: 193 	 Loss: 7.8354
# Epoch: 194 	 Loss: 7.8354
# Epoch: 195 	 Loss: 7.8354
# Epoch: 196 	 Loss: 7.8354
# Epoch: 197 	 Loss: 7.8354
# Epoch: 198 	 Loss: 7.8354
# Epoch: 199 	 Loss: 7.8354
# Total Duration: 26.055327892303467

# %% [markdown]
# ## Testing

# %%
loss_batch = []
for x_batch, y_batch, batch in generate_batch_data(x_test, y_test, batch_size):
    predicted_output = model(x_batch.reshape(10,1,4))
    loss = criterion(predicted_output, y_batch.reshape(10,1,4))
    print('Sample: %d \t Loss: %.4f' \
             %(batch, loss ))


end_time = time()
print('Total Duration: {}'.format(end_time - start_time))
# Out:
# Sample: 0 	 Loss: 7.6049
# Sample: 1 	 Loss: 8.6917
# Sample: 2 	 Loss: 5.3018
# Sample: 3 	 Loss: 6.6343
# Sample: 4 	 Loss: 4.7847
# Sample: 5 	 Loss: 5.2040
# Sample: 6 	 Loss: 6.6725
# Sample: 7 	 Loss: 5.3917
# Sample: 8 	 Loss: 6.4272
# Sample: 9 	 Loss: 4.2720
# Sample: 10 	 Loss: 6.8821
# Sample: 11 	 Loss: 7.7148
# Sample: 12 	 Loss: 7.1834
# Sample: 13 	 Loss: 6.6920
# Sample: 14 	 Loss: 6.1261
# Sample: 15 	 Loss: 5.4388
# Sample: 16 	 Loss: 7.1759
# Sample: 17 	 Loss: 10.5715
# Sample: 18 	 Loss: 5.2581
# Sample: 19 	 Loss: 4.0771
# Sample: 20 	 Loss: 6.5687
# Sample: 21 	 Loss: 6.3125
# Sample: 22 	 Loss: 6.3383
# Sample: 23 	 Loss: 4.3989
# Sample: 24 	 Loss: 7.5510
# Sample: 25 	 Loss: 7.3582
# Sample: 26 	 Loss: 5.9990
# Sample: 27 	 Loss: 5.1936
# Sample: 28 	 Loss: 6.2914
# Sample: 29 	 Loss: 5.8972
# Sample: 30 	 Loss: 6.3425
# Sample: 31 	 Loss: 7.2617
# Sample: 32 	 Loss: 6.3866
# Sample: 33 	 Loss: 5.0514
# Sample: 34 	 Loss: 7.5515
# Sample: 35 	 Loss: 7.6403
# Sample: 36 	 Loss: 8.0360
# Sample: 37 	 Loss: 5.7391
# Sample: 38 	 Loss: 6.0209
# Sample: 39 	 Loss: 5.9438
# Sample: 40 	 Loss: 5.8011
# Sample: 41 	 Loss: 6.8552
# Sample: 42 	 Loss: 7.0959
# Sample: 43 	 Loss: 5.4899
# Sample: 44 	 Loss: 5.4949
# Sample: 45 	 Loss: 6.7413
# Sample: 46 	 Loss: 7.8893
# Sample: 47 	 Loss: 9.2965
# Sample: 48 	 Loss: 5.7065
# Sample: 49 	 Loss: 7.7054
# Total Duration: 26.073248863220215

# %% [markdown]
# ## Plot a test trajectory

# %%
x_in = x_batch.detach().numpy()
print(x_in.shape)
y_out = predicted_output.reshape(10,4).detach().numpy()
y_out.shape
# Out:
# (10, 4)
# (10, 4)

# %%
plt.figure(figsize=(30,10))
plt.title('Predict values vs Actual values of States', fontsize=30)
plt.xlabel('time', fontsize=20)
plt.ylabel('State', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.plot(np.arange(10), y_out[:,0], 'r',      label=r'predicted $\theta_1$', linewidth = 2.0)
plt.plot(np.arange(10), x_in[:,0], 'r' + ':', label=r'actual $\theta_1$', linewidth = 2.0)
plt.plot(np.arange(10), y_out[:,1], 'b',      label=r'predicted $\theta_2$', linewidth = 2.0)
plt.plot(np.arange(10), x_in[:,1], 'b' + ':', label=r'actual $\theta_2$', linewidth = 2.0)
plt.legend()
# plt.legend(['predicted $\theta_1$','actual $\theta_1$','predicted $\theta_2$','actual $\theta_2$'])
# plt.show()
plt.savefig('predicted vs actual.png', dpi=72)
# plt.close()
